# %%
l=[1,2,3,4,5,6,7,8,9]
l1 = []
for i in l:
    l1.append(i**2)

# %%
print(l1)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
[ i for i in l if i % 2 ==0]
# Out:
# [2, 4, 6, 8]

# %%
l1=["harshit","skills","kumar","data science"]

# %%
[i.upper() for i in l1]
# Out:
# ['HARSHIT', 'SKILLS', 'KUMAR', 'DATA SCIENCE']

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
d={"key1":1, "key2":2,"key3":3,"key4":4}

# %%
{k:v**2 for k , v in d.items()}
# Out:
# {'key1': 1, 'key2': 4, 'key3': 9, 'key4': 16}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3), ('key4', 4)])

# %%
d
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}

# %%
{k:v for k, v in d.items() if v>1}
# Out:
# {'key2': 2, 'key3': 3, 'key4': 4}

# %%
def test():
  pass

# %%
def test1():
  print("this is my first function")

# %%
test1()
# Out:
# this is my first function

# %%
test1() +"hashit"
# Out:
# this is my first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2174/2158850439.py in <cell line: 0>()
# ----> 1 test1() +"hashit"
#
# TypeError: can only concatenate tuple (not "str") to tuple

# %%
def test2():
    return "this is my first return"

# %%
test2()
# Out:
# 'this is my first return'

# %%
test2()+" harshit"
# Out:
# 'this is my first return harshit'

# %%
def test3():
  return "harshit",23,345.56,[1,2,33]

# %%
test3()
# Out:
# ('harshit', 23, 345.56, [1, 2, 33])

# %%
print(type(test3))
# Out:
# <class 'function'>

# %%
type(test3)
# Out:
# function

# %%
a,b,c,d = test3()

# %%
print(test3())
# Out:
# ('harshit', 23, 345.56, [1, 2, 33])

# %%
print( a,b,c,d)
# Out:
# harshit 23 345.56 [1, 2, 33]

# %%
def add():
    a =5+7/6
    return a

# %%
add()
# Out:
# 6.166666666666667

# %%
def test5(a,b,c):
  d=a+b/c
  return d

# %%
test5(4,5,6.4)
# Out:
# 4.78125

# %%
test5(2,5,8)
# Out:
# 2.625

# %%
def test6(a,b):
  return a+b

# %%
test6(5,4)
# Out:
# 9

# %%
test6("harshit","yadav")
# Out:
# 'harshityadav'

# %%
test6((1,2,"harshit"),(4,5,"yadav"))
# Out:
# (1, 2, 'harshit', 4, 5, 'yadav')

# %%
)
# Out:
#   File "/tmp/ipykernel_2174/687023194.py", line 1
#     )
#     ^
# SyntaxError: unmatched ')'

# %%
def test11(*args):
  return args +(1,2,3,4)

# %%
type(test11())
# Out:
# tuple

# %%
test11(1,2,3)
# Out:
# (1, 2, 3, 1, 2, 3, 4)

# %%
type(test11())
# Out:
# tuple

# %%
def test11(*kwargs):
  return kwargs +(1,2,3,4)

# %%
type(test11())
# Out:
# tuple

# %%
test11()
# Out:
# (1, 2, 3, 4)

# %%
test11(1,2,3,"harshit","yadav",[1,2,3,4,5,4])
# Out:
# (1, 2, 3, 'harshit', 'yadav', [1, 2, 3, 4, 5, 4], 1, 2, 3, 4)

# %%
type(test11())
# Out:
# tuple

# %%
def test12(*harshit):
  return harshit

# %%
type(test12())
# Out:
# tuple

# %%
test12(1,2,34,4)
# Out:
# (1, 2, 34, 4)

# %%
def test13(*args,a):
  return args,a

# %%
test13(1,2,3,4, a=34)
# Out:
# ((1, 2, 3, 4), 34)

# %%
def test14(c,d,a=23,b=1):
  return a,b,c,d

# %%
test14()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2174/3076521518.py in <cell line: 0>()
# ----> 1 test14()
#
# TypeError: test14() missing 2 required positional arguments: 'c' and 'd'

# %%
test14(3,4)
# Out:
# (23, 1, 3, 4)

# %%
test14(2,5,a=2342)
# Out:
# (2342, 1, 2, 5)

# %%
def test15(**kwargs):
  return kwargs

# %%
test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a=[1,2,3,4],b="harshit",c=23.34)

# %%
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b == 0:
        return "Division by zero is not possible."
    return a / b

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("\nChoose Operation")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = input("Enter your choice (1/2/3/4): ")

if choice == "1":
    print("Result =", add(num1, num2))
elif choice == "2":
    print("Result =", subtract(num1, num2))
elif choice == "3":
    print("Result =", multiply(num1, num2))
elif choice == "4":
    print("Result =", divide(num1, num2))
else:
    print("Invalid Choice")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_430/3751301469.py in <cell line: 0>()
#      13     return a / b
#      14
# ---> 15 num1 = float(input("Enter first number: "))
#      16 num2 = float(input("Enter second number: "))
#      17
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
balance = 10000
pin = 1234

print("====== WELCOME TO ATM ======")

user_pin = int(input("Enter your PIN: "))

if user_pin == pin:

    print("1. Check Balance")
    print("2. Withdraw Money")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        print("Your Balance is:", balance)

    elif choice == 2:
        amount = int(input("Enter amount: "))

        if amount <= balance:
            balance = balance - amount
            print("Please Collect Your Cash")
            print("Remaining Balance:", balance)
        else:
            print("Insufficient Balance")

    else:
        print("Invalid Choice")

else:
    print("Wrong PIN")
# Out:
# ====== WELCOME TO ATM ======
# Enter your PIN: 1234
# 1. Check Balance
# 2. Withdraw Money
# Enter your choice: 2
# Enter amount: 1000
# Please Collect Your Cash
# Remaining Balance: 9000
