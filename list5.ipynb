# %%
l=[1,2,3,4,4,"subh","kumar",324.456,"abc"]

# %%
l1_num =[]
l2_str=[]
for i in l:
  if type (i)==int or type(i)==float:
    l1_num.append(i)
  else:
    l2_str.append(i)
    print(l1_num)
    print(l2_str)
# Out:
# [1, 2, 3, 4, 4]
# ['subh']
# [1, 2, 3, 4, 4]
# ['subh', 'kumar']
# [1, 2, 3, 4, 4, 324.456]
# ['subh', 'kumar', 'abc']

# %%
list=[1,2,3,4,"harshit","mohan",3.14,2.34,True]

# %%
from IPython.core.shellapp import boolean_flag
l1_num =[]
l2_str=[]
l3_float=[]
l4_boolean=[]
for i in l:
  if type(i)==int
   l1_num.append(i)
if type(i)==str
  l2_str.appemd(i)
if type(i)==float
   l3_float.append(i)
else:
    l4_boolean.append(i)

    print(l1_num)
    print(l2_str)
    print(l3_float)
    print(l4_boolean)
# Out:
#   File "/tmp/ipykernel_1045/3257500755.py", line 7
#     if type(i)==int
#                    ^
# SyntaxError: expected ':'

# %%
my_list = [1, 2, 3, 4, "harshit", "mohan", 3.14, 2.34, True]

int_list = []
str_list = []
float_list = []
bool_list = []

for item in my_list:
    if type(item) == bool:
        bool_list.append(item)
    elif type(item) == int:
        int_list.append(item)
    elif type(item) == float:
        float_list.append(item)
    elif type(item) == str:
        str_list.append(item)
    else:
        print("Unknown data type")

print("Integer List:", int_list)
print("String List:", str_list)
print("Float List:", float_list)
print("Boolean List:", bool_list)
# Out:
# Integer List: [1, 2, 3, 4]
# String List: ['harshit', 'mohan']
# Float List: [3.14, 2.34]
# Boolean List: [True]

# %%
l=[5,9,6,7,8,9,2,3,18,19]

# %%
print(sum(l))
# Out:
# 86

# %%
l = [5, 9, 6, 7, 8, 9, 2, 3, 18, 19]

s = 0
index = 0

for i in l:
    if index % 2 != 0:
        s = s + i
    index = index + 1

print("Sum of odd index elements:", s)
# Out:
# Sum of odd index elements: 47

# %%
dict={'name':"harshit",'num':34,'range':45,'subject':"english"}

# %%
keys=[]
values=[]
for item in dict.items():
  keys.append(item[0]),values.append(item[1])
  print("keys:",keys)
  print("values:",values)
# Out:
# keys: ['name']
# values: ['harshit']
# keys: ['name', 'num']
# values: ['harshit', 34]
# keys: ['name', 'num', 'range']
# values: ['harshit', 34, 45]
# keys: ['name', 'num', 'range', 'subject']
# values: ['harshit', 34, 45, 'english']

# %%
print(keys)
print(values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1617/2012583962.py in <cell line: 0>()
# ----> 1 print(keys)
#       2 print(values)
#
# NameError: name 'keys' is not defined

# %%
x = int(input("Enter a number: "))

temp = x
reverse = 0

while x > 0:
    digit = x % 10
    reverse = (reverse * 10) + digit
    x = x // 10

if temp == reverse:
    print("The number is palindrome.")
else:
    print("The number is not palindrome.")
# Out:
# Enter a number: 121
# The number is palindrome.
